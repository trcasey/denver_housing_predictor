# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from xml.etree import ElementTree as ET

plt.style.use('ggplot')

# %matplotlib inline

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ## Importing the datasets

# %%
df_sales = pd.read_csv('datasets/real_property_sales_and_transfers.csv')

# %%
df_parcels = pd.read_csv('datasets/parcels.csv')

# %%
df_characteristics = pd.read_csv('datasets/real_property_residential_characteristics.csv', error_bad_lines=False)
# Out:
# Skipping line 63332: expected 46 fields, saw 47
# Skipping line 63335: expected 46 fields, saw 47
# Skipping line 63338: expected 46 fields, saw 47
#
# Skipping line 68348: expected 46 fields, saw 48
# Skipping line 69469: expected 46 fields, saw 47
# Skipping line 69470: expected 46 fields, saw 47
# Skipping line 69471: expected 46 fields, saw 47
# Skipping line 69472: expected 46 fields, saw 47

# %% [markdown]
# ## Filtering the data to only show single family homes

# %%
single_family_home_id = '113'
single_family_home_definition = 'SINGLE FAMILY'

df_sales = df_sales[df_sales.D_CLASS == single_family_home_id]

# %%
df_parcels = df_parcels[df_parcels.D_CLASS == single_family_home_id]

# %%
df_characteristics = df_characteristics[df_characteristics.D_CLASS_CN == single_family_home_definition]

# %% [markdown]
# ## df_parcels Data Dictionary

# %%
parcels_document_tree = ET.parse( './datasets/parcels.xml' )

# %%
attributes = []
attr_definitions = []

for attribute in parcels_document_tree.iter('attr'):
    attributes.append(attribute.find('attrlabl').text)
    attr_definitions.append(attribute.find('attrdef').text)
    
parcels_data_dict = pd.DataFrame({'attribute': attributes,
                                  'definition': attr_definitions})

parcels_data_dict
# Out:
#                    attribute  \
# 0                   OBJECTID
# 1                        PIN
# 2                   SCHEDNUM
# 3                     MAPNUM
# 4                     BLKNUM
# 5                  PARCELNUM
# 6                  APPENDAGE
# 7              PARCEL_SOURCE
# 8          SYSTEM_START_DATE
# 9                 OWNER_NAME
# 10       OWNER_ADDRESS_LINE1
# 11       OWNER_ADDRESS_LINE2
# 12     OWNER_ADDR_NBR_PREFIX
# 13            OWNER_ADDR_NBR
# 14     OWNER_ADDR_NBR_SUFFIX
# 15    OWNER_STR_NAME_PRE_MOD
# 16    OWNER_STR_NAME_PRE_DIR
# 17   OWNER_STR_NAME_PRE_TYPE
# 18            OWNER_STR_NAME
# 19  OWNER_STR_NAME_POST_TYPE
# 20   OWNER_STR_NAME_POST_DIR
# 21   OWNER_STR_NAME_POST_MOD
# 22           OWNER_UNIT_TYPE
# 23          OWNER_UNIT_IDENT
# 24                OWNER_CITY
# 25               OWNER_STATE
# 26                 OWNER_ZIP
# 27          SITUS_ADDRESS_ID
# 28       SITUS_ADDRESS_LINE1
# 29       SITUS_ADDRESS_LINE2
# 30                SITUS_CITY
# 31               SITUS_STATE
# 32                 SITUS_ZIP
# 33            SITUS_ADDR_NBR
# 34     SITUS_ADDR_NBR_SUFFIX
# 35    SITUS_STR_NAME_PRE_MOD
# 36    SITUS_STR_NAME_PRE_DIR
# 37   SITUS_STR_NAME_PRE_TYPE
# 38            SITUS_STR_NAME
# 39  SITUS_STR_NAME_POST_TYPE
# 40   SITUS_STR_NAME_POST_DIR
# 41   SITUS_STR_NAME_POST_MOD
# 42           SITUS_UNIT_TYPE
# 43          SITUS_UNIT_IDENT
# 44                  TAX_DIST
# 45                PROP_CLASS
# 46                LAND_VALUE
# 47         IMPROVEMENT_VALUE
# 48               TOTAL_VALUE
# 49              IMPROVEMENTS
# 50                      LAND
# 51                     DCL12
# 52                   D_CLASS
# 53                D_CLASS_CN
# 54                  ACT_ZONE
# 55                  IMP_AREA
# 56                   CCYRBLT
# 57                ASAL_INSTR
# 58             SALE_MONTHDAY
# 59                 SALE_YEAR
# 60                SALE_PRICE
# 61             RECEPTION_NUM
# 62                     SHAPE
# 63                  GLOBALID
# 64              SHAPE_Length
# 65                SHAPE_Area
#
#                                            definition
# 0                            Internal feature number.
# 1   The replacement parcel number in the Manatron ...
# 2   Assessment Parcel Schedule Number is a 13 digi...
# 3   Assessment Index Map number - the first five d...
# 4   Assessment Block Number - the sixth and sevent...
# 5   Assessment Parcel Number - the eighth, ninth, ...
# 6   Assessment Appendage Number - the last three d...
# 7   Contractor shifted parcel geometry for coincid...
# 8   The date the parcel geometry entered into the ...
# 9                                    Owner of Record.
# 10  USPS Deliver Address Line for owner mailing ad...
# 11  USPS Secondary address unit designator of stre...
# 12        Owner mailing street address number prefix.
# 13               Owner mailing street address number.
# 14        Owner mailing street address number suffix.
# 15  Owner's mailing address name component which f...
# 16                 Owner's mailing address direction.
# 17             Owner mailing address street pre-type.
# 18               Owner's mailing address street name.
# 19               Owner's mailing address street type.
# 20          Owner's mailing address post directional.
# 21  Owner's mailing address name component which f...
# 22                        Owner's mailing unit type.
# 23           Owner's mailing address unit/apt number.
# 24                      Owner's Mailing Address City.
# 25                 Owner's Mailing Address State Code
# 26                   Owner's Mailing Address Zip Code
# 27                                 Address Identifier
# 28  USPS Deliver Address Line for street address u...
# 29  USPS Secondary address unit designator of stre...
# 30                 City in which property is located.
# 31                State in which property is located.
# 32  Postal zip code boundary within which property...
# 33  Situs (property location) mailing street addre...
# 34  Situs (property location) mailing street addre...
# 35  Situs (property location) mailing address name...
# 36  Situs (property location) mailing address dire...
# 37  Situs (property location) mailing address stre...
# 38  Situs (property location) mailing address stre...
# 39  Situs (property location) mailing address stre...
# 40  Situs (property location) mailing address post...
# 41  Situs (property location) mailing address name...
# 42      Situs (property location) mailing unit type.
# 43  Situs (property location) mailing address unit...
# 44                           Tax District for Parcel.
# 45                                Property Class Code
# 46                                 Land Actual Value.
# 47     Improvements (Parcel Structures) Actual Value.
# 48                                Actual Total value.
# 49  Improvements (Parcel Structures) Assessesd Value.
# 50                               Land Square Footage.
# 51                                  Property Use Code
# 52                                 Denver Class Code.
# 53                         Denver Class Code Defined.
# 54  Zone for Property valuation.  Note: Zoning is ...
# 55  Improvements (Parcel Structures) Area (square ...
# 56                                        Year Built.
# 57         Sale Instrument (Recording Document) Type.
# 58                          Date (Month/Day) of Sale.
# 59                                      Year of Sale.
# 60                               Property sale price.
# 61                             Sale Recording Number.
# 62                                  Feature geometry.
# 63  A field of type UUID (Universal Unique Identif...
# 64               Length of feature in internal units.
# 65         Area of feature in internal units squared.

# %% [markdown]
# ## df_sales Data Dictionary

# %%
sales_dict = pd.read_excel('datasets/RealPropertyMetaData.xlsx', sheetname='Sales_Transfers', header=3, parse_cols=[1,2,3,5])
sales_dict
# Out:
#         Field Name             Example Column Type  \
# 0              PIN           163752899        Text
# 1         SCHEDNUM       0231416005000        Text
# 2    RECEPTION_NUM          2011148564        Text
# 3   RECEPTION_DATE            20101004        Text
# 4       INSTRUMENT                  WD        Text
# 5        SALE_YEAR                2010        Text
# 6    SALE_MONTHDAY                0928        Text
# 7       SALE_PRICE              199677        Text
# 8          GRANTOR  SMITH, JOHN & JANE        Text
# 9          GRANTEE        BROWN, JAMES        Text
# 10      D_CLASS_CN       SINGLE FAMILY        Text
# 11          NBHD_1                 248      Double
# 12       NBHD_1_CN       E SLOANS LAKE        Text
#
#                                   Description
# 0   Assessor's Property Identification Number
# 1                  Assessor's Schedule Number
# 2         Clerk & Recorder's Reception Number
# 3           Clerk & Recorder's Reception Date
# 4                          Type of Instrument
# 5                                   Sale Year
# 6                              Sale Month/Day
# 7                                  Sale Price
# 8           Person(s) relinquishing ownership
# 9               Person(s) recieving ownership
# 10     Property Use Class(D-CLASS) Definition
# 11                          Neighborhood code
# 12                          Neighborhood name

# %% [markdown]
# ## df_characteristics Data Dictionary

# %%
characteristics_dict = pd.read_excel('datasets/RealPropertyMetaData.xlsx', sheetname='Residential_Characteristics', header=3, parse_cols=[1,2,3,5])
characteristics_dict
# Out:
#           Field Name                    Example    Column Type  \
# 0                PIN                  161714761           Text
# 1           SCHEDNUM              0226327008000           Text
# 2                 CD                         01           Text
# 3             OFCARD                         01           Text
# 4              OWNER                SMITH, JOHN           Text
# 5           CO_OWNER                      TYLER           Text
# 6          OWNER_NUM                     003650           Text
# 7          OWNER_DIR                          S           Text
# 8           OWNER_ST                   YOSEMITE           Text
# 9         OWNER_TYPE                         ST           Text
# 10         OWNER_APT                       #300           Text
# 11        OWNER_CITY                     DENVER           Text
# 12       OWNER_STATE                         CO           Text
# 13         OWNER_ZIP                      80237           Text
# 14          SITE_NBR                       3114           Text
# 15          SITE_DIR                          S           Text
# 16         SITE_NAME                    LARIMER           Text
# 17         SITE_MODE                         ST           Text
# 18         SITE_MORE                        #A3           Text
# 19          TAX_DIST                     DENVER           Text
# 20        PROP_CLASS                       1112           Text
# 21    PROPERTY_CLASS  Single Family Residential           Text
# 22            ZONE10                   1C-MU-30           Text
# 23        D_CLASS_CN              SINGLE FAMILY           Text
# 24         LAND_SQFT                       6241   Long Integer
# 25          AREA_ABG                       1411   Long Integer
# 26         BSMT_AREA                        389   Long Integer
# 27        FBSMT_SQFT                        389   Long Integer
# 28          GRD_AREA                          0   Long Integer
# 29             STORY                          1          Float
# 30          STYLE_CN                  TWO-STORY           Text
# 31           BED_RMS                          3  Short Integer
# 32            FULL_B                          2  Short Integer
# 33             HLF_B                          1  Short Integer
# 34           CCYRBLT                       1958   Long Integer
# 35          CCAGE_RM                       2004   Long Integer
# 36             UNITS                         50           text
# 37    ASMT_APPR_LAND                      62400   Long Integer
# 38       TOTAL_VALUE                     261700   Long Integer
# 39           ASDLAND                      18096   Long Integer
# 40      ASSESS_VALUE                      75893   Long Integer
# 41      ASMT_TAXABLE                     524220   Long Integer
# 42   ASMT_EXEMPT_AMT                          0   Long Integer
# 43            NBHD_1                          4         double
# 44         NBHD_1_CN                  GATEWAY N           Text
# 45  LEGL_DESCRIPTION                        NaN           Text
#
#                                   Description
# 0   Assessor's Property Identification Number
# 1                  Assessor's Schedule Number
# 2                             Building Number
# 3                         Number of Buildings
# 4                                       Owner
# 5                                    Co-Owner
# 6                       Street Mailing Number
# 7                    Street Mailing Direction
# 8                  Street Mailing Street Name
# 9                         Street Mailing Type
# 10                 Street Mailing Unit Number
# 11                               Mailing City
# 12                              Mailing State
# 13                                   Zip Code
# 14                         Site Street Number
# 15                      Site Street Direction
# 16                           Site Street Name
# 17                           Site Street Type
# 18                           Site Unit Number
# 19                               Tax District
# 20             Property Class(ASMT-PROP-CODE)
# 21                 Property Class Description
# 22                                       Zone
# 23     Property Use Class(D-CLASS) Definition
# 24                                  Land Area
# 25               Above Grade Improvement Area
# 26                    Basement Square Footage
# 27                     Finished Basement Area
# 28                Garden Level Square Footage
# 29                                    Stories
# 30         Architecture Style Code Definition
# 31              Number of bedroom above grade
# 32                 Total number of full baths
# 33                 Total number of half baths
# 34                                 Year Built
# 35                               Remodel Year
# 36                            Number of Units
# 37                          Actual Land Value
# 38                         Actual Total Value
# 39                        Assessed Land Value
# 40                       Assessed Total Value
# 41                             Taxable Amount
# 42                              Exempt Amount
# 43                         Neighborhood code
# 44                          Neighborhood name
# 45    Description of the parcel per the deed

# %% [markdown]
# ## Looking at summary statistics and the basic shape of the data

# %% [markdown]
# ### *df_parcels* AKA: the dataset with the basic info on each parcel

# %%
df_parcels.shape
# Out:
# (84680, 62)

# %%
df_parcels.describe()
# Out:
#                 PIN      SCHEDNUM        MAPNUM        BLKNUM     PARCELNUM  \
# count  8.468000e+04  8.468000e+04  84653.000000  84653.000000  84653.000000
# mean   1.614567e+08  3.624098e+11   3623.820526     14.310857     15.396005
# std    7.991908e+05  2.279490e+11   2279.597412      9.977237     15.353878
# min    1.604314e+08  4.100122e+09    141.000000      0.000000      1.000000
# 25%    1.607884e+08  1.324410e+11   1324.000000      6.000000      6.000000
# 50%    1.613910e+08  5.036270e+11   5036.000000     13.000000     13.000000
# 75%    1.618580e+08  5.263090e+11   5263.000000     21.000000     20.000000
# max    1.640949e+08  9.131140e+11   9131.000000     67.000000    783.000000
#
#           APPENDAGE  OWNER_ADDRESS_LINE2  OWNER_STR_NAME_PRE_MOD  \
# count  84653.000000                  0.0                     0.0
# mean       0.212207                  NaN                     NaN
# std       14.551307                  NaN                     NaN
# min        0.000000                  NaN                     NaN
# 25%        0.000000                  NaN                     NaN
# 50%        0.000000                  NaN                     NaN
# 75%        0.000000                  NaN                     NaN
# max      998.000000                  NaN                     NaN
#
#        OWNER_STR_NAME_PRE_TYPE  SITUS_ADDRESS_ID      ...        IMPROVEMENTS  \
# count                      0.0      84447.000000      ...        84657.000000
# mean                       NaN      89114.276659      ...        11242.301003
# std                        NaN      69092.544573      ...         5904.469386
# min                        NaN         20.000000      ...            0.000000
# 25%                        NaN      34223.500000      ...         7522.000000
# 50%                        NaN      89723.000000      ...        10627.000000
# 75%                        NaN     125887.500000      ...        14169.000000
# max                        NaN     528900.000000      ...       231469.000000
#
#          PROP_CLASS   TOTAL_VALUE           LAND    DCL12      IMP_AREA  \
# count  84657.000000  8.465700e+04   84675.000000  84680.0  84680.000000
# mean    1147.963275  2.575711e+05    6622.977266     11.0   1251.029617
# std      539.151225  1.072444e+05    2869.185751      0.0    486.527351
# min     1112.000000  3.460000e+04       0.000000     11.0      0.000000
# 25%     1112.000000  1.734000e+05    5400.000000     11.0    926.000000
# 50%     1112.000000  2.356000e+05    6250.000000     11.0   1122.000000
# 75%     1112.000000  3.205000e+05    7500.000000     11.0   1447.000000
# max     9279.000000  4.510400e+06  366283.000000     11.0   7004.000000
#
#             CCYRBLT  SALE_MONTHDAY     SALE_YEAR    SALE_PRICE
# count  84668.000000   76671.000000  76671.000000  5.378100e+04
# mean    1950.651557     634.708495   2005.830027  2.246357e+05
# std       39.326479     334.532109     12.181676  9.624427e+05
# min        0.000000     101.000000    104.000000  1.000000e+00
# 25%     1930.000000     327.000000   2001.000000  1.000000e+01
# 50%     1953.000000     618.000000   2007.000000  1.512000e+05
# 75%     1968.000000     917.000000   2013.000000  2.409000e+05
# max     2016.000000    1231.000000   2016.000000  3.350000e+07
#
# [8 rows x 26 columns]

# %%
df_parcels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84680 entries, 24 to 225554
# Data columns (total 62 columns):
# PIN                         84680 non-null int64
# SCHEDNUM                    84680 non-null int64
# MAPNUM                      84653 non-null float64
# BLKNUM                      84653 non-null float64
# PARCELNUM                   84653 non-null float64
# APPENDAGE                   84653 non-null float64
# PARCEL_SOURCE               81689 non-null object
# SYSTEM_START_DATE           84680 non-null object
# OWNER_NAME                  84660 non-null object
# OWNER_ADDRESS_LINE1         84660 non-null object
# OWNER_ADDRESS_LINE2         0 non-null float64
# OWNER_ADDR_NBR_PREFIX       0 non-null object
# OWNER_ADDR_NBR              84659 non-null object
# OWNER_ADDR_NBR_SUFFIX       12 non-null object
# OWNER_STR_NAME_PRE_MOD      0 non-null float64
# OWNER_STR_NAME_PRE_DIR      43821 non-null object
# OWNER_STR_NAME_PRE_TYPE     0 non-null float64
# OWNER_STR_NAME              84660 non-null object
# OWNER_STR_NAME_POST_TYPE    82103 non-null object
# OWNER_STR_NAME_POST_DIR     204 non-null object
# OWNER_STR_NAME_POST_MOD     0 non-null object
# OWNER_UNIT_TYPE             2512 non-null object
# OWNER_UNIT_IDENT            2618 non-null object
# OWNER_CITY                  84660 non-null object
# OWNER_STATE                 84660 non-null object
# OWNER_ZIP                   84658 non-null object
# SITUS_ADDRESS_ID            84447 non-null float64
# SITUS_ADDRESS_LINE1         84680 non-null object
# SITUS_ADDRESS_LINE2         0 non-null float64
# SITUS_CITY                  84680 non-null object
# SITUS_STATE                 84680 non-null object
# SITUS_ZIP                   83241 non-null object
# SITUS_ADDR_NBR              84680 non-null object
# SITUS_ADDR_NBR_SUFFIX       0 non-null object
# SITUS_STR_NAME_PRE_MOD      0 non-null float64
# SITUS_STR_NAME_PRE_DIR      46931 non-null object
# SITUS_STR_NAME_PRE_TYPE     0 non-null float64
# SITUS_STR_NAME              84680 non-null object
# SITUS_STR_NAME_POST_TYPE    84643 non-null object
# SITUS_STR_NAME_POST_DIR     0 non-null object
# SITUS_STR_NAME_POST_MOD     0 non-null float64
# SITUS_UNIT_TYPE             173 non-null object
# SITUS_UNIT_IDENT            385 non-null object
# TAX_DIST                    84680 non-null object
# LAND_VALUE                  84657 non-null float64
# IMPROVEMENT_VALUE           84657 non-null float64
# IMPROVEMENTS                84657 non-null float64
# PROP_CLASS                  84657 non-null float64
# TOTAL_VALUE                 84657 non-null float64
# LAND                        84675 non-null float64
# D_CLASS                     84680 non-null object
# D_CLASS_CN                  84680 non-null object
# DCL12                       84680 non-null float64
# ACT_ZONE                    84680 non-null object
# IMP_AREA                    84680 non-null float64
# CCYRBLT                     84668 non-null float64
# ASAL_INSTR                  76671 non-null object
# SALE_MONTHDAY               76671 non-null float64
# SALE_YEAR                   76671 non-null float64
# SALE_PRICE                  53781 non-null float64
# RECEPTION_NUM               76671 non-null object
# GLOBALID                    84680 non-null object
# dtypes: float64(24), int64(2), object(36)
# memory usage: 40.7+ MB

# %% [markdown]
# ### *df_sales* AKA: the dataset with the home sales info

# %%
df_sales.shape
# Out:
# (74221, 16)

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74221 entries, 38 to 234014
# Data columns (total 16 columns):
# SCHEDNUM          74221 non-null int64
# RECEPTION_NUM     74221 non-null object
# INSTRUMENT        74221 non-null object
# SALE_YEAR         74221 non-null int64
# SALE_MONTHDAY     74221 non-null int64
# RECEPTION_DATE    74221 non-null int64
# SALE_PRICE        49205 non-null float64
# GRANTOR           74221 non-null object
# GRANTEE           74221 non-null object
# CLASS             74221 non-null object
# MKT_CLUS          74212 non-null float64
# D_CLASS           74221 non-null object
# D_CLASS_CN        74221 non-null object
# NBHD_1            74221 non-null int64
# NBHD_1_CN         74221 non-null object
# PIN               74221 non-null int64
# dtypes: float64(2), int64(6), object(8)
# memory usage: 9.6+ MB

# %%
df_sales.describe()
# Out:
#            SCHEDNUM     SALE_YEAR  SALE_MONTHDAY  RECEPTION_DATE  \
# count  7.422100e+04  74221.000000   74221.000000    7.422100e+04
# mean   3.300750e+11   2011.727234     659.805203    2.011868e+07
# std    2.361227e+11      2.649423     332.156548    2.652223e+04
# min    4.100122e+09   2008.000000     101.000000    1.990081e+07
# 25%    1.165070e+11   2009.000000     407.000000    2.009110e+07
# 50%    2.351300e+11   2012.000000     627.000000    2.012051e+07
# 75%    5.233060e+11   2014.000000     923.000000    2.014091e+07
# max    9.131140e+11   2016.000000    1231.000000    2.016091e+07
#
#          SALE_PRICE      MKT_CLUS        NBHD_1           PIN
# count  4.920500e+04  74212.000000  74221.000000  7.422100e+04
# mean   3.979828e+05     14.462324    334.796068  1.615791e+08
# std    1.774349e+06     10.052962    250.564454  9.303221e+05
# min    1.000000e+00      1.000000      1.000000  1.604314e+08
# 25%    7.500000e+04      6.000000    109.000000  1.607881e+08
# 50%    1.805000e+05     13.000000    259.000000  1.614388e+08
# 75%    2.910000e+05     23.000000    541.000000  1.619761e+08
# max    3.350000e+07     56.000000    906.000000  1.640949e+08

# %%
df_sales.D_CLASS_CN.value_counts()
# Out:
# SINGLE FAMILY    74221
# Name: D_CLASS_CN, dtype: int64

# %% [markdown]
# ### df_characteristics AKA the dataset with the characteristics of the property

# %%
df_characteristics.shape
# Out:
# (131640, 46)

# %%
df_characteristics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131640 entries, 0 to 199731
# Data columns (total 46 columns):
# PIN                 131640 non-null int64
# SCHEDNUM            131640 non-null int64
# CD                  131640 non-null int64
# OFCARD              131640 non-null int64
# OWNER               131640 non-null object
# CO_OWNER            2651 non-null object
# OWNER_NUM           131640 non-null object
# OWNER_DIR           70057 non-null object
# OWNER_ST            131640 non-null object
# OWNER_TYPE          128336 non-null object
# OWNER_APT           4717 non-null object
# OWNER_CITY          131640 non-null object
# OWNER_STATE         131639 non-null object
# OWNER_ZIP           131634 non-null object
# SITE_NBR            131640 non-null int64
# SITE_DIR            74512 non-null object
# SITE_NAME           131640 non-null object
# SITE_MODE           131597 non-null object
# SITE_MORE           1666 non-null object
# TAX_DIST            131640 non-null object
# PROP_CLASS          131639 non-null float64
# PROPERTY_CLASS      131639 non-null object
# ZONE10              131640 non-null object
# D_CLASS_CN          131640 non-null object
# LAND_SQFT           131623 non-null float64
# AREA_ABG            131640 non-null int64
# BSMT_AREA           131640 non-null int64
# FBSMT_SQFT          131640 non-null int64
# GRD_AREA            131640 non-null int64
# STORY               131640 non-null float64
# STYLE_CN            131625 non-null object
# BED_RMS             131640 non-null int64
# FULL_B              131625 non-null float64
# HLF_B               131625 non-null float64
# CCYRBLT             131625 non-null float64
# CCAGE_RM            131625 non-null float64
# UNITS               131640 non-null int64
# ASMT_APPR_LAND      131639 non-null float64
# TOTAL_VALUE         131639 non-null float64
# ASDLAND             131639 non-null float64
# ASSESS_VALUE        131639 non-null float64
# ASMT_TAXABLE        131639 non-null float64
# ASMT_EXEMPT_AMT     131639 non-null float64
# NBHD_1              131640 non-null int64
# NBHD_1_CN           131640 non-null object
# LEGL_DESCRIPTION    131640 non-null object
# dtypes: float64(13), int64(12), object(21)
# memory usage: 47.2+ MB

# %%
df_characteristics.describe()
# Out:
#                 PIN      SCHEDNUM        CD         OFCARD       SITE_NBR  \
# count  1.316400e+05  1.316400e+05  131640.0  131640.000000  131640.000000
# mean   1.615375e+08  3.943676e+11       1.0       1.002978    3600.228851
# std    8.285440e+05  2.274046e+11       0.0       0.094791    3840.690532
# min    1.604314e+08  4.100122e+09       1.0       1.000000       1.000000
# 25%    1.608711e+08  2.184110e+11       1.0       1.000000    1357.000000
# 50%    1.614421e+08  5.085090e+11       1.0       1.000000    2747.000000
# 75%    1.619073e+08  5.303080e+11       1.0       1.000000    4459.000000
# max    1.640952e+08  9.145050e+11       1.0      25.000000   21680.000000
#
#           PROP_CLASS      LAND_SQFT       AREA_ABG      BSMT_AREA  \
# count  131639.000000  131623.000000  131640.000000  131640.000000
# mean     1139.693791    6887.373651    1489.297129     671.045943
# std       473.359897    3670.260932     782.577253     552.215525
# min      1112.000000       0.000000       0.000000       0.000000
# 25%      1112.000000    5350.000000     974.000000       0.000000
# 50%      1112.000000    6250.000000    1245.000000     754.000000
# 75%      1112.000000    7680.000000    1764.000000    1051.000000
# max      9279.000000  366283.000000   18231.000000    8896.000000
#
#           FBSMT_SQFT      ...              CCYRBLT       CCAGE_RM  \
# count  131640.000000      ...        131625.000000  131625.000000
# mean      380.999218      ...          1951.716862     617.746294
# std       475.986018      ...            32.779802     925.027109
# min         0.000000      ...          1873.000000       0.000000
# 25%         0.000000      ...          1927.000000       0.000000
# 50%         0.000000      ...          1953.000000       0.000000
# 75%       768.000000      ...          1971.000000    1997.000000
# max      7565.000000      ...          2016.000000    3994.000000
#
#                UNITS  ASMT_APPR_LAND   TOTAL_VALUE        ASDLAND  \
# count  131640.000000    1.316390e+05  1.316390e+05  131639.000000
# mean        1.027925    1.549733e+05  3.592385e+05   12339.774087
# std         0.285891    1.567984e+05  2.905924e+05   12491.454724
# min         0.000000    0.000000e+00  3.460000e+04       0.000000
# 25%         1.000000    5.620000e+04  1.938000e+05    4474.000000
# 50%         1.000000    9.690000e+04  2.914000e+05    7713.000000
# 75%         1.000000    2.186000e+05  4.223500e+05   17401.000000
# max        10.000000    8.690200e+06  1.009460e+07  691740.000000
#
#         ASSESS_VALUE   ASMT_TAXABLE  ASMT_EXEMPT_AMT         NBHD_1
# count  131639.000000  131639.000000    131639.000000  131640.000000
# mean    28602.434529   28502.675651       100.683019     403.264304
# std     23143.031543   23101.119558      2755.915865     240.839512
# min      2754.000000       0.000000         0.000000       1.000000
# 25%     15426.000000   15360.000000         0.000000     205.000000
# 50%     23196.000000   23150.000000         0.000000     520.000000
# 75%     33623.000000   33580.000000         0.000000     588.000000
# max    803530.000000  803530.000000    380430.000000     906.000000
#
# [8 rows x 25 columns]

# %% [markdown]
# ## Looking at one property across all three datasets

# %%
df_sales[df_sales.SCHEDNUM == 23307028000]
# Out:
#           SCHEDNUM RECEPTION_NUM INSTRUMENT  SALE_YEAR  SALE_MONTHDAY  \
# 18205  23307028000    2016099458         WD       2016            722
# 18206  23307028000    2012005557         SW       2011           1215
# 18207  23307028000    2010142026         QC       2010           1124
# 18208  23307028000    2011096228         PT       2011            829
# 18209  23307028000    2015111855         QC       2015            807
#
#        RECEPTION_DATE  SALE_PRICE                    GRANTOR  \
# 18205        20160728    330000.0          WASHINGTON,QUIANA
# 18206        20120117    185000.0  NAVY FEDERAL CREDIT UNION
# 18207        20101207         NaN  NADOL,DAVID J & THERESE J
# 18208        20110829         NaN            NADOL,THERESE J
# 18209        20150811         1.0          WASHINGTON,QUIANA
#
#                          GRANTEE CLASS  MKT_CLUS D_CLASS     D_CLASS_CN  \
# 18205     PHIFER,DONALD & NICOLE     R       1.0     113  SINGLE FAMILY
# 18206          WASHINGTON,QUIANA     R       1.0     113  SINGLE FAMILY
# 18207            NADOL,THERESE J     R       1.0     113  SINGLE FAMILY
# 18208  NAVY FEDERAL CREDIT UNION     R       1.0     113  SINGLE FAMILY
# 18209          WASHINGTON,QUIANA     R       1.0     113  SINGLE FAMILY
#
#        NBHD_1     NBHD_1_CN        PIN
# 18205       3  GREEN VALLEY  162802499
# 18206       3  GREEN VALLEY  162802499
# 18207       3  GREEN VALLEY  162802499
# 18208       3  GREEN VALLEY  162802499
# 18209       3  GREEN VALLEY  162802499

# %%
df_parcels[df_parcels.SCHEDNUM == 23307028000]
# Out:
#             PIN     SCHEDNUM  MAPNUM  BLKNUM  PARCELNUM  APPENDAGE  \
# 6864  162802499  23307028000   233.0     7.0       28.0        0.0
#
#      PARCEL_SOURCE    SYSTEM_START_DATE              OWNER_NAME  \
# 6864                2010-12-08 00:00:00  PHIFER,DONALD & NICOLE
#
#      OWNER_ADDRESS_LINE1                   ...                    DCL12  \
# 6864     4063 JERICHO ST                   ...                     11.0
#
#           ACT_ZONE IMP_AREA CCYRBLT  ASAL_INSTR SALE_MONTHDAY  SALE_YEAR  \
# 6864  R-2-A          2144.0  2000.0          QC         807.0     2015.0
#
#      SALE_PRICE RECEPTION_NUM                                GLOBALID
# 6864        1.0    2015111855  {00000000-0000-0000-0000-000000000000}
#
# [1 rows x 62 columns]

# %%
df_characteristics[df_characteristics.SCHEDNUM == 23307028000]
# Out:
#              PIN     SCHEDNUM  CD  OFCARD                      OWNER CO_OWNER  \
# 14053  162802499  23307028000   1       1  PHIFER,DONALD AND NICOLE       NaN
#
#       OWNER_NUM OWNER_DIR OWNER_ST OWNER_TYPE  \
# 14053    4063         NaN  JERICHO         ST
#
#                       ...                 UNITS ASMT_APPR_LAND TOTAL_VALUE  \
# 14053                 ...                     1        37400.0    262200.0
#
#       ASDLAND  ASSESS_VALUE ASMT_TAXABLE ASMT_EXEMPT_AMT NBHD_1     NBHD_1_CN  \
# 14053  2977.0       20871.0      20870.0             0.0      3  GREEN VALLEY
#
#                          LEGL_DESCRIPTION
# 14053  GREEN VALLEY RANCH FLG #26 B5  L28
#
# [1 rows x 46 columns]

# %%
df_sales = df_sales[df_sales.D_CLASS == '113']

# %%
df_sales.head()
# Out:
#          SCHEDNUM RECEPTION_NUM INSTRUMENT  SALE_YEAR  SALE_MONTHDAY  \
# 38     4100122000    2008170400         PR       2008           1212
# 1050  14101001000    2015157653         WD       2015           1102
# 1051  14101001000    2009074518         WD       2009            605
# 1052  14101001000    2009002129         WD       2008           1024
# 1053  14101001000    2008138043         WD       2008            703
#
#       RECEPTION_DATE  SALE_PRICE                 GRANTOR  \
# 38          20081222         NaN  REITHER,JOHN G & CLARA
# 1050        20151109    415000.0   PADBURY,CHRISTOPHER R
# 1051        20090615    299000.0        ATKINSON,RUSSELL
# 1052        20090108        10.0      DREAM BUILDERS LLC
# 1053        20081008        10.0        ATKINSON,RUSSELL
#
#                           GRANTEE CLASS  MKT_CLUS D_CLASS     D_CLASS_CN  \
# 38    REITHER,JOHN FAMILY TRUST &     R       2.0     113  SINGLE FAMILY
# 1050         MACIEL,HORACIO PEREZ     R       6.0     113  SINGLE FAMILY
# 1051        PADBURY,CHRISTOPHER R     R       6.0     113  SINGLE FAMILY
# 1052             ATKINSON,RUSSELL     R       6.0     113  SINGLE FAMILY
# 1053           DREAM BUILDERS LLC     R       6.0     113  SINGLE FAMILY
#
#       NBHD_1       NBHD_1_CN        PIN
# 38         4       GATEWAY N  160431419
# 1050       5  N GREEN VALLEY  163111346
# 1051       5  N GREEN VALLEY  163111346
# 1052       5  N GREEN VALLEY  163111346
# 1053       5  N GREEN VALLEY  163111346

# %%
df_parcels.head()
# Out:
#           PIN      SCHEDNUM  MAPNUM  BLKNUM  PARCELNUM  APPENDAGE  \
# 24  163338863   22120010000   221.0    20.0       10.0        0.0
# 26  163172116   22117007000   221.0    17.0        7.0        0.0
# 30  163339266   22122009000   221.0    22.0        9.0        0.0
# 31  163338812   22120005000   221.0    20.0        5.0        0.0
# 32  160507547  113701032000  1137.0     1.0       32.0        0.0
#
#    PARCEL_SOURCE    SYSTEM_START_DATE                      OWNER_NAME  \
# 24                2010-12-08 00:00:00            CABRAL,CARLOS MADERA
# 26                2010-12-08 00:00:00              ARELLANO,GERALDINE
# 30                2010-12-08 00:00:00  QUINQUILLA,VANESSA M RODRIGUEZ
# 31                2010-12-08 00:00:00           GOLDSCHMIDT,ARI RONEL
# 32                2010-12-08 00:00:00            DUKE PARTNERS II LLC
#
#           OWNER_ADDRESS_LINE1                   ...                    DCL12  \
# 24              7769 PECOS ST                   ...                     11.0
# 26            19767 E 47TH PL                   ...                     11.0
# 30            19198 E 47TH DR                   ...                     11.0
# 31             4789 BISCAY ST                   ...                     11.0
# 32  2015 MANHATTAN BEACH BLVD                   ...                     11.0
#
#         ACT_ZONE IMP_AREA CCYRBLT  ASAL_INSTR SALE_MONTHDAY  SALE_YEAR  \
# 24  R-2            1612.0  2005.0          QC        1210.0     2015.0
# 26  R-2-A          1508.0  2004.0          SW         406.0     2004.0
# 30  R-2            1743.0  2012.0          WD         208.0     2013.0
# 31  R-2            1910.0  2005.0          WD         730.0     2015.0
# 32  S-SU-D         1868.0  1972.0          QC         123.0     2001.0
#
#    SALE_PRICE RECEPTION_NUM                                GLOBALID
# 24       10.0    2015179877  {00000000-0000-0000-0000-000000000000}
# 26       10.0    2004092229  {00000000-0000-0000-0000-000000000000}
# 30   205400.0    2013021152  {00000000-0000-0000-0000-000000000000}
# 31   245000.0    2015109807  {00000000-0000-0000-0000-000000000000}
# 32        NaN    0000205065  {00000000-0000-0000-0000-000000000000}
#
# [5 rows x 62 columns]

# %% [markdown]
# ## Comparing columns between dataframes

# %%
for column in df_sales.columns.sort_values():
    print column
# Out:
# CLASS
# D_CLASS
# D_CLASS_CN
# GRANTEE
# GRANTOR
# INSTRUMENT
# MKT_CLUS
# NBHD_1
# NBHD_1_CN
# PIN
# RECEPTION_DATE
# RECEPTION_NUM
# SALE_MONTHDAY
# SALE_PRICE
# SALE_YEAR
# SCHEDNUM

# %%
for column in df_parcels.columns:
    print column
# Out:
# PIN
# SCHEDNUM
# MAPNUM
# BLKNUM
# PARCELNUM
# APPENDAGE
# PARCEL_SOURCE
# SYSTEM_START_DATE
# OWNER_NAME
# OWNER_ADDRESS_LINE1
# OWNER_ADDRESS_LINE2
# OWNER_ADDR_NBR_PREFIX
# OWNER_ADDR_NBR
# OWNER_ADDR_NBR_SUFFIX
# OWNER_STR_NAME_PRE_MOD
# OWNER_STR_NAME_PRE_DIR
# OWNER_STR_NAME_PRE_TYPE
# OWNER_STR_NAME
# OWNER_STR_NAME_POST_TYPE
# OWNER_STR_NAME_POST_DIR
# OWNER_STR_NAME_POST_MOD
# OWNER_UNIT_TYPE
# OWNER_UNIT_IDENT
# OWNER_CITY
# OWNER_STATE
# OWNER_ZIP
# SITUS_ADDRESS_ID
# SITUS_ADDRESS_LINE1
# SITUS_ADDRESS_LINE2
# SITUS_CITY
# SITUS_STATE
# SITUS_ZIP
# SITUS_ADDR_NBR
# SITUS_ADDR_NBR_SUFFIX
# SITUS_STR_NAME_PRE_MOD
# SITUS_STR_NAME_PRE_DIR
# SITUS_STR_NAME_PRE_TYPE
# SITUS_STR_NAME
# SITUS_STR_NAME_POST_TYPE
# SITUS_STR_NAME_POST_DIR
# SITUS_STR_NAME_POST_MOD
# SITUS_UNIT_TYPE
# SITUS_UNIT_IDENT
# TAX_DIST
# LAND_VALUE
# IMPROVEMENT_VALUE
# IMPROVEMENTS
# PROP_CLASS
# TOTAL_VALUE
# LAND
# D_CLASS
# D_CLASS_CN
# DCL12
# ACT_ZONE
# IMP_AREA
# CCYRBLT
# ASAL_INSTR
# SALE_MONTHDAY
# SALE_YEAR
# SALE_PRICE
# RECEPTION_NUM
# GLOBALID

# %%
for column in df_characteristics.columns.sort_values():
    print column
# Out:
# AREA_ABG
# ASDLAND
# ASMT_APPR_LAND
# ASMT_EXEMPT_AMT
# ASMT_TAXABLE
# ASSESS_VALUE
# BED_RMS
# BSMT_AREA
# CCAGE_RM
# CCYRBLT
# CD
# CO_OWNER
# D_CLASS_CN
# FBSMT_SQFT
# FULL_B
# GRD_AREA
# HLF_B
# LAND_SQFT
# LEGL_DESCRIPTION
# NBHD_1
# NBHD_1_CN
# OFCARD
# OWNER
# OWNER_APT
# OWNER_CITY
# OWNER_DIR
# OWNER_NUM
# OWNER_ST
# OWNER_STATE
# OWNER_TYPE
# OWNER_ZIP
# PIN
# PROPERTY_CLASS
# PROP_CLASS
# SCHEDNUM
# SITE_DIR
# SITE_MODE
# SITE_MORE
# SITE_NAME
# SITE_NBR
# STORY
# STYLE_CN
# TAX_DIST
# TOTAL_VALUE
# UNITS
# ZONE10

# %% [markdown]
# ## Combining the dataframes

# %%
df_merge = df_sales.merge(df_parcels, how='left', on='SCHEDNUM')

# %%
df_merge = df_merge.merge(df_characteristics, how='left', on='SCHEDNUM')

# %% [markdown]
# ## Looking over the new dataframe for any problems

# %%
df_merge.describe()
# Out:
#            SCHEDNUM   SALE_YEAR_x  SALE_MONTHDAY_x  RECEPTION_DATE  \
# count  7.422100e+04  74221.000000     74221.000000    7.422100e+04
# mean   3.300750e+11   2011.727234       659.805203    2.011868e+07
# std    2.361227e+11      2.649423       332.156548    2.652223e+04
# min    4.100122e+09   2008.000000       101.000000    1.990081e+07
# 25%    1.165070e+11   2009.000000       407.000000    2.009110e+07
# 50%    2.351300e+11   2012.000000       627.000000    2.012051e+07
# 75%    5.233060e+11   2014.000000       923.000000    2.014091e+07
# max    9.131140e+11   2016.000000      1231.000000    2.016091e+07
#
#        SALE_PRICE_x      MKT_CLUS      NBHD_1_x         PIN_x         PIN_y  \
# count  4.920500e+04  74212.000000  74221.000000  7.422100e+04  7.419400e+04
# mean   3.979828e+05     14.462324    334.796068  1.615791e+08  1.615789e+08
# std    1.774349e+06     10.052962    250.564454  9.303221e+05  9.300915e+05
# min    1.000000e+00      1.000000      1.000000  1.604314e+08  1.604314e+08
# 25%    7.500000e+04      6.000000    109.000000  1.607881e+08  1.607880e+08
# 50%    1.805000e+05     13.000000    259.000000  1.614388e+08  1.614387e+08
# 75%    2.910000e+05     23.000000    541.000000  1.619761e+08  1.619760e+08
# max    3.350000e+07     56.000000    906.000000  1.640949e+08  1.640949e+08
#
#              MAPNUM      ...          CCYRBLT_y      CCAGE_RM         UNITS  \
# count  74185.000000      ...       74177.000000  74177.000000  74194.000000
# mean    3300.131199      ...        1956.389164    491.082249      1.025123
# std     2361.415282      ...          33.105469    861.420152      0.249139
# min      141.000000      ...        1873.000000      0.000000      0.000000
# 25%     1165.000000      ...        1941.000000      0.000000      1.000000
# 50%     2351.000000      ...        1954.000000      0.000000      1.000000
# 75%     5233.000000      ...        1980.000000      0.000000      1.000000
# max     9131.000000      ...        2016.000000   3986.000000      9.000000
#
#        ASMT_APPR_LAND  TOTAL_VALUE_y        ASDLAND   ASSESS_VALUE  \
# count    7.419400e+04   7.419400e+04   74194.000000   74194.000000
# mean     1.040168e+05   2.545047e+05    8281.061811   20260.487802
# std      9.155052e+04   1.072965e+05    7293.350188    8547.225300
# min      0.000000e+00   3.460000e+04       0.000000    2754.000000
# 25%      4.120000e+04   1.727000e+05    3280.000000   13747.000000
# 50%      6.390000e+04   2.274000e+05    5094.000000   18101.000000
# 75%      1.360000e+05   3.162000e+05   10826.000000   25170.000000
# max      1.363400e+06   1.363800e+06  108527.000000  116029.000000
#
#         ASMT_TAXABLE  ASMT_EXEMPT_AMT      NBHD_1_y
# count   74194.000000     74194.000000  74194.000000
# mean    20250.630644        10.796628    334.766261
# std      8543.449814       690.785562    250.586779
# min         0.000000         0.000000      1.000000
# 25%     13750.000000         0.000000    109.000000
# 50%     18100.000000         0.000000    259.000000
# 75%     25170.000000         0.000000    541.000000
# max    108560.000000    116030.000000    906.000000
#
# [8 rows x 57 columns]

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74221 entries, 0 to 74220
# Columns: 122 entries, SCHEDNUM to LEGL_DESCRIPTION
# dtypes: float64(51), int64(6), object(65)
# memory usage: 69.7+ MB

# %%
df_merge.iloc[1]
# Out:
# SCHEDNUM                                        14101001000
# RECEPTION_NUM_x                                  2015157653
# INSTRUMENT                                               WD
# SALE_YEAR_x                                            2015
# SALE_MONTHDAY_x                                        1102
# RECEPTION_DATE                                     20151109
# SALE_PRICE_x                                         415000
# GRANTOR                               PADBURY,CHRISTOPHER R
# GRANTEE                                MACIEL,HORACIO PEREZ
# CLASS                                                     R
# MKT_CLUS                                                  6
# D_CLASS_x                                               113
# D_CLASS_CN_x                                  SINGLE FAMILY
# NBHD_1_x                                                  5
# NBHD_1_CN_x                                  N GREEN VALLEY
# PIN_x                                             163111346
# PIN_y                                           1.63111e+08
# MAPNUM                                                  141
# BLKNUM                                                    1
# PARCELNUM                                                 1
# APPENDAGE                                                 0
# PARCEL_SOURCE
# SYSTEM_START_DATE                       2010-12-08 00:00:00
# OWNER_NAME                             MACIEL,HORACIO PEREZ
# OWNER_ADDRESS_LINE1                      5201 NETHERLAND ST
# OWNER_ADDRESS_LINE2                                     NaN
# OWNER_ADDR_NBR_PREFIX                                   NaN
# OWNER_ADDR_NBR                                         5201
# OWNER_ADDR_NBR_SUFFIX                                   NaN
# OWNER_STR_NAME_PRE_MOD                                  NaN
#                                         ...
# SITE_NAME                                        NETHERLAND
# SITE_MODE                                                ST
# SITE_MORE                                               NaN
# TAX_DIST_y                                             151D
# PROP_CLASS_y                                           1112
# PROPERTY_CLASS                    Single Family Residential
# ZONE10                                         C-MU-20
# D_CLASS_CN                                    SINGLE FAMILY
# LAND_SQFT                                              8622
# AREA_ABG                                               4130
# BSMT_AREA                                              1771
# FBSMT_SQFT                                                0
# GRD_AREA                                                  0
# STORY                                                     2
# STYLE_CN                                          TWO-STORY
# BED_RMS                                                   5
# FULL_B                                                    5
# HLF_B                                                     0
# CCYRBLT_y                                              2005
# CCAGE_RM                                                  0
# UNITS                                                     1
# ASMT_APPR_LAND                                        55500
# TOTAL_VALUE_y                                        397900
# ASDLAND                                                4418
# ASSESS_VALUE                                          31673
# ASMT_TAXABLE                                          31680
# ASMT_EXEMPT_AMT                                           0
# NBHD_1_y                                                  5
# NBHD_1_CN_y                                  N GREEN VALLEY
# LEGL_DESCRIPTION          GREEN VALLEY RANCH FLG #36 B1  L1
# Name: 1, dtype: object

# %% [markdown]
# ## Creating a datetime column from the data and making it the index

# %%
days = []
months = []
years = df_merge.SALE_YEAR_x.astype(str)
datetimes = []

for row in df_merge.SALE_MONTHDAY_x:
    row = str(row)
    if len(row) < 4:
        row = '0' + row
    days.append(row[:-2])
    months.append(row[2:])

# %%
df_merge['date'] = years + '-' + months + '-' + days

# %%
df_merge['date'] = pd.to_datetime(df_merge['date'], format='%Y-%d-%m')

# %%
df_merge.index = df_merge.date

# %%
df_merge['year'] = df_merge.index.year
df_merge['month'] = df_merge.index.month

# %% [markdown]
# ## Ordering the observations by date

# %%
df_merge.sort_values('date', inplace=True)

# %% [markdown]
# ## Looking at the sales by year

# %%
df_merge.groupby('year').size()
# Out:
# year
# 2008    11962
# 2009     8439
# 2010     7716
# 2011     7302
# 2012     7836
# 2013     7986
# 2014     7547
# 2015     9158
# 2016     6275
# dtype: int64

# %%
df_yearly_sales = df_merge[['SCHEDNUM']].resample('A').count()

axis = df_yearly_sales.plot(figsize=(18, 5));

axis.set_title("Sales by Year")

# %%
df_monthly_sales = df_merge[['SCHEDNUM']].resample('M').count()

axis = df_monthly_sales.plot(figsize=(18, 5));

axis.set_title("Sales by Month")

# %%
sales_in_2015 = df_merge[['SCHEDNUM']][(df_merge.year == 2015)].resample('M').count()

axis = sales_in_2015.plot(figsize=(18,5));

axis.set_title("Monthly Home Sales in 2015")

# %%
for column in df_merge:
    print column, df_merge[column].count()
# Out:
# SCHEDNUM 74221
# RECEPTION_NUM_x 74221
# INSTRUMENT 74221
# SALE_YEAR_x 74221
# SALE_MONTHDAY_x 74221
# RECEPTION_DATE 74221
# SALE_PRICE_x 49205
# GRANTOR 74221
# GRANTEE 74221
# CLASS 74221
# MKT_CLUS 74212
# D_CLASS_x 74221
# D_CLASS_CN_x 74221
# NBHD_1_x 74221
# NBHD_1_CN_x 74221
# PIN_x 74221
# PIN_y 74194
# MAPNUM 74185
# BLKNUM 74185
# PARCELNUM 74185
# APPENDAGE 74185
# PARCEL_SOURCE 70694
# SYSTEM_START_DATE 74194
# OWNER_NAME 74193
# OWNER_ADDRESS_LINE1 74193
# OWNER_ADDRESS_LINE2 0
# OWNER_ADDR_NBR_PREFIX 0
# OWNER_ADDR_NBR 74192
# OWNER_ADDR_NBR_SUFFIX 10
# OWNER_STR_NAME_PRE_MOD 0
# OWNER_STR_NAME_PRE_DIR 36613
# OWNER_STR_NAME_PRE_TYPE 0
# OWNER_STR_NAME 74193
# OWNER_STR_NAME_POST_TYPE 71934
# OWNER_STR_NAME_POST_DIR 182
# OWNER_STR_NAME_POST_MOD 0
# OWNER_UNIT_TYPE 3674
# OWNER_UNIT_IDENT 3876
# OWNER_CITY_x 74193
# OWNER_STATE_x 74193
# OWNER_ZIP_x 74188
# SITUS_ADDRESS_ID 74005
# SITUS_ADDRESS_LINE1 74194
# SITUS_ADDRESS_LINE2 0
# SITUS_CITY 74194
# SITUS_STATE 74194
# SITUS_ZIP 72418
# SITUS_ADDR_NBR 74194
# SITUS_ADDR_NBR_SUFFIX 0
# SITUS_STR_NAME_PRE_MOD 0
# SITUS_STR_NAME_PRE_DIR 39869
# SITUS_STR_NAME_PRE_TYPE 0
# SITUS_STR_NAME 74194
# SITUS_STR_NAME_POST_TYPE 74155
# SITUS_STR_NAME_POST_DIR 0
# SITUS_STR_NAME_POST_MOD 0
# SITUS_UNIT_TYPE 207
# SITUS_UNIT_IDENT 368
# TAX_DIST_x 74194
# LAND_VALUE 74191
# IMPROVEMENT_VALUE 74191
# IMPROVEMENTS 74191
# PROP_CLASS_x 74191
# TOTAL_VALUE_x 74191
# LAND 74190
# D_CLASS_y 74194
# D_CLASS_CN_y 74194
# DCL12 74194
# ACT_ZONE 74194
# IMP_AREA 74194
# CCYRBLT_x 74177
# ASAL_INSTR 73658
# SALE_MONTHDAY_y 73658
# SALE_YEAR_y 73658
# SALE_PRICE_y 50892
# RECEPTION_NUM_y 73658
# GLOBALID 74194
# PIN 74194
# CD 74194
# OFCARD 74194
# OWNER 74194
# CO_OWNER 1746
# OWNER_NUM 74194
# OWNER_DIR 36616
# OWNER_ST 74194
# OWNER_TYPE 71943
# OWNER_APT 3865
# OWNER_CITY_y 74194
# OWNER_STATE_y 74194
# OWNER_ZIP_y 74191
# SITE_NBR 74194
# SITE_DIR 39871
# SITE_NAME 74194
# SITE_MODE 74155
# SITE_MORE 369
# TAX_DIST_y 74194
# PROP_CLASS_y 74194
# PROPERTY_CLASS 74194
# ZONE10 74194
# D_CLASS_CN 74194
# LAND_SQFT 74190
# AREA_ABG 74194
# BSMT_AREA 74194
# FBSMT_SQFT 74194
# GRD_AREA 74194
# STORY 74194
# STYLE_CN 74177
# BED_RMS 74194
# FULL_B 74177
# HLF_B 74177
# CCYRBLT_y 74177
# CCAGE_RM 74177
# UNITS 74194
# ASMT_APPR_LAND 74194
# TOTAL_VALUE_y 74194
# ASDLAND 74194
# ASSESS_VALUE 74194
# ASMT_TAXABLE 74194
# ASMT_EXEMPT_AMT 74194
# NBHD_1_y 74194
# NBHD_1_CN_y 74194
# LEGL_DESCRIPTION 74194
# date 74221
# year 74221
# month 74221

# %%
df_wd = df_merge[df_merge.INSTRUMENT == 'WD']

# %%
df_wd.shape
# Out:
# (34386, 125)

# %%
for column in df_wd:
    print column, df_wd[column].count()
# Out:
# SCHEDNUM 34386
# RECEPTION_NUM_x 34386
# INSTRUMENT 34386
# SALE_YEAR_x 34386
# SALE_MONTHDAY_x 34386
# RECEPTION_DATE 34386
# SALE_PRICE_x 32104
# GRANTOR 34386
# GRANTEE 34386
# CLASS 34386
# MKT_CLUS 34382
# D_CLASS_x 34386
# D_CLASS_CN_x 34386
# NBHD_1_x 34386
# NBHD_1_CN_x 34386
# PIN_x 34386
# PIN_y 34374
# MAPNUM 34371
# BLKNUM 34371
# PARCELNUM 34371
# APPENDAGE 34371
# PARCEL_SOURCE 32277
# SYSTEM_START_DATE 34374
# OWNER_NAME 34373
# OWNER_ADDRESS_LINE1 34373
# OWNER_ADDRESS_LINE2 0
# OWNER_ADDR_NBR_PREFIX 0
# OWNER_ADDR_NBR 34372
# OWNER_ADDR_NBR_SUFFIX 6
# OWNER_STR_NAME_PRE_MOD 0
# OWNER_STR_NAME_PRE_DIR 16652
# OWNER_STR_NAME_PRE_TYPE 0
# OWNER_STR_NAME 34373
# OWNER_STR_NAME_POST_TYPE 33592
# OWNER_STR_NAME_POST_DIR 82
# OWNER_STR_NAME_POST_MOD 0
# OWNER_UNIT_TYPE 1541
# OWNER_UNIT_IDENT 1639
# OWNER_CITY_x 34373
# OWNER_STATE_x 34373
# OWNER_ZIP_x 34369
# SITUS_ADDRESS_ID 34290
# SITUS_ADDRESS_LINE1 34374
# SITUS_ADDRESS_LINE2 0
# SITUS_CITY 34374
# SITUS_STATE 34374
# SITUS_ZIP 33430
# SITUS_ADDR_NBR 34374
# SITUS_ADDR_NBR_SUFFIX 0
# SITUS_STR_NAME_PRE_MOD 0
# SITUS_STR_NAME_PRE_DIR 18082
# SITUS_STR_NAME_PRE_TYPE 0
# SITUS_STR_NAME 34374
# SITUS_STR_NAME_POST_TYPE 34364
# SITUS_STR_NAME_POST_DIR 0
# SITUS_STR_NAME_POST_MOD 0
# SITUS_UNIT_TYPE 104
# SITUS_UNIT_IDENT 174
# TAX_DIST_x 34374
# LAND_VALUE 34373
# IMPROVEMENT_VALUE 34373
# IMPROVEMENTS 34373
# PROP_CLASS_x 34373
# TOTAL_VALUE_x 34373
# LAND 34373
# D_CLASS_y 34374
# D_CLASS_CN_y 34374
# DCL12 34374
# ACT_ZONE 34374
# IMP_AREA 34374
# CCYRBLT_x 34371
# ASAL_INSTR 34131
# SALE_MONTHDAY_y 34131
# SALE_YEAR_y 34131
# SALE_PRICE_y 28888
# RECEPTION_NUM_y 34131
# GLOBALID 34374
# PIN 34371
# CD 34371
# OFCARD 34371
# OWNER 34371
# CO_OWNER 748
# OWNER_NUM 34371
# OWNER_DIR 16650
# OWNER_ST 34371
# OWNER_TYPE 33594
# OWNER_APT 1631
# OWNER_CITY_y 34371
# OWNER_STATE_y 34371
# OWNER_ZIP_y 34368
# SITE_NBR 34371
# SITE_DIR 18081
# SITE_NAME 34371
# SITE_MODE 34361
# SITE_MORE 174
# TAX_DIST_y 34371
# PROP_CLASS_y 34371
# PROPERTY_CLASS 34371
# ZONE10 34371
# D_CLASS_CN 34371
# LAND_SQFT 34370
# AREA_ABG 34371
# BSMT_AREA 34371
# FBSMT_SQFT 34371
# GRD_AREA 34371
# STORY 34371
# STYLE_CN 34368
# BED_RMS 34371
# FULL_B 34368
# HLF_B 34368
# CCYRBLT_y 34368
# CCAGE_RM 34368
# UNITS 34371
# ASMT_APPR_LAND 34371
# TOTAL_VALUE_y 34371
# ASDLAND 34371
# ASSESS_VALUE 34371
# ASMT_TAXABLE 34371
# ASMT_EXEMPT_AMT 34371
# NBHD_1_y 34371
# NBHD_1_CN_y 34371
# LEGL_DESCRIPTION 34371
# date 34386
# year 34386
# month 34386

# %%
df_wd.groupby('SALE_YEAR').count()
# Out:
#            SCHEDNUM  RECEPTION_NUM  INSTRUMENT  SALE_MONTHDAY  RECEPTION_DATE  \
# SALE_YEAR
# 2008           3764           3764        3764           3764            3764
# 2009           3343           3343        3343           3343            3343
# 2010           2796           2796        2796           2796            2796
# 2011           2800           2800        2800           2800            2800
# 2012           3455           3455        3455           3455            3455
# 2013           4183           4183        4183           4183            4183
# 2014           4478           4478        4478           4478            4478
# 2015           5565           5565        5565           5565            5565
# 2016           4002           4002        4002           4002            4002
#
#            SALE_PRICE  GRANTOR  GRANTEE  CLASS  MKT_CLUS    ...     \
# SALE_YEAR                                                   ...
# 2008             3386     3764     3764   3764      3764    ...
# 2009             3084     3343     3343   3343      3342    ...
# 2010             2502     2796     2796   2796      2796    ...
# 2011             2464     2800     2800   2800      2800    ...
# 2012             3097     3455     3455   3455      3455    ...
# 2013             3916     4183     4183   4183      4183    ...
# 2014             4332     4478     4478   4478      4478    ...
# 2015             5434     5565     5565   5565      5565    ...
# 2016             3889     4002     4002   4002      3999    ...
#
#            ASMT_APPR_LAND  TOTAL_VALUE  ASDLAND  ASSESS_VALUE  ASMT_TAXABLE  \
# SALE_YEAR
# 2008                 3764         3764     3764          3764          3764
# 2009                 3343         3343     3343          3343          3343
# 2010                 2796         2796     2796          2796          2796
# 2011                 2799         2799     2799          2799          2799
# 2012                 3455         3455     3455          3455          3455
# 2013                 4183         4183     4183          4183          4183
# 2014                 4476         4476     4476          4476          4476
# 2015                 5558         5558     5558          5558          5558
# 2016                 3997         3997     3997          3997          3997
#
#            ASMT_EXEMPT_AMT  NBHD_1_y  NBHD_1_CN_y  LEGL_DESCRIPTION  datetime
# SALE_YEAR
# 2008                  3764      3764         3764              3764      3764
# 2009                  3343      3343         3343              3343      3343
# 2010                  2796      2796         2796              2796      2796
# 2011                  2799      2799         2799              2799      2800
# 2012                  3455      3455         3455              3455      3455
# 2013                  4183      4183         4183              4183      4183
# 2014                  4476      4476         4476              4476      4478
# 2015                  5558      5558         5558              5558      5565
# 2016                  3997      3997         3997              3997      4002
#
# [9 rows x 61 columns]

# %%
axis = df_wd.SALE_PRICE.plot(figsize=(16, 5))

axis.set_title("Daily Sales");

# %% [markdown]
# ### Looking at different characteristics of homes in Denver

# %%
df_characteristics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131640 entries, 0 to 199731
# Data columns (total 46 columns):
# PIN                 131640 non-null int64
# SCHEDNUM            131640 non-null int64
# CD                  131640 non-null int64
# OFCARD              131640 non-null int64
# OWNER               131640 non-null object
# CO_OWNER            2651 non-null object
# OWNER_NUM           131640 non-null object
# OWNER_DIR           70057 non-null object
# OWNER_ST            131640 non-null object
# OWNER_TYPE          128336 non-null object
# OWNER_APT           4717 non-null object
# OWNER_CITY          131640 non-null object
# OWNER_STATE         131639 non-null object
# OWNER_ZIP           131634 non-null object
# SITE_NBR            131640 non-null int64
# SITE_DIR            74512 non-null object
# SITE_NAME           131640 non-null object
# SITE_MODE           131597 non-null object
# SITE_MORE           1666 non-null object
# TAX_DIST            131640 non-null object
# PROP_CLASS          131639 non-null float64
# PROPERTY_CLASS      131639 non-null object
# ZONE10              131640 non-null object
# D_CLASS_CN          131640 non-null object
# LAND_SQFT           131623 non-null float64
# AREA_ABG            131640 non-null int64
# BSMT_AREA           131640 non-null int64
# FBSMT_SQFT          131640 non-null int64
# GRD_AREA            131640 non-null int64
# STORY               131640 non-null float64
# STYLE_CN            131625 non-null object
# BED_RMS             131640 non-null int64
# FULL_B              131625 non-null float64
# HLF_B               131625 non-null float64
# CCYRBLT             131625 non-null float64
# CCAGE_RM            131625 non-null float64
# UNITS               131640 non-null int64
# ASMT_APPR_LAND      131639 non-null float64
# TOTAL_VALUE         131639 non-null float64
# ASDLAND             131639 non-null float64
# ASSESS_VALUE        131639 non-null float64
# ASMT_TAXABLE        131639 non-null float64
# ASMT_EXEMPT_AMT     131639 non-null float64
# NBHD_1              131640 non-null int64
# NBHD_1_CN           131640 non-null object
# LEGL_DESCRIPTION    131640 non-null object
# dtypes: float64(13), int64(12), object(21)
# memory usage: 47.2+ MB

# %%
df_characteristics.groupby('BED_RMS').size().plot(kind='bar', figsize=(16,5), 
                                                  title='Distribution of Bedroom Counts in all Denver Single Family Homes', 
                                                  logy=True);

# %%
df_characteristics.groupby('FULL_B').size().plot(kind='bar', figsize=(16,5), 
                                                  title='Distribution of Full Bathroom Counts in Denver Single Family Homes', 
                                                  logy=True);

# %%
df_characteristics.groupby('HLF_B').size().plot(kind='bar', figsize=(16,5), 
                                                  title='Distribution of Half Bathroom Counts in all Denver Single Family Homes', 
                                                  logy=True);

# %%
df_characteristics.groupby('CCYRBLT').size().plot(kind='bar', figsize=(16,5), 
                                                  title='Year All Homes in Denver were Built', 
                                                  logy=True);
